# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.
#
# Analysis
#
# 1) The average wind speed ranges between 0 - 10 mph, and very rarely exceeds 10mph.
# 2) The is a greater ammount of cities with 0% cloudiness than 100%.
# 3) Cities positioned around 0 degrees latitude experience a maller range of humidity than other cities tested.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

saved_lats = []
saved_longs = []

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    #also add estimated latitude and longitude
    if city not in cities:
        cities.append(city)
        saved_lats.append(lat_lng[0])
        saved_longs.append(lat_lng[1])
        
# print(citipy.nearest_city(0, 0).keys())

# Print the city count to confirm sufficient count
print("{} cities have been identified to poll for weather".format(len(cities)))

city_list = pd.DataFrame({"City":cities, "Approx. Latitude":saved_lats, "Approx. Longitude":saved_longs})
# city_list = pd.DataFrame({"City":cities})

#save to a csv (for reference - can compare estimated coordinates to actual coordinates if there is time, which cannot be done
#easily with citipy because the references only go one way -> approx. coordinates to city name, not city name to actual 
#coordinates)
city_list.to_csv("./CityNameList.csv")
city_list.head()
# Out:
# 627 cities have been identified to poll for weather
#                    City  Approx. Latitude  Approx. Longitude
# 0                 praya         -9.763516         115.801979
# 1            chokurdakh         78.292473         150.038906
# 2  vila franca do campo         38.226696         -23.002314
# 3               ushuaia        -60.312647         -51.111650
# 4            butaritari         13.461073         160.792719

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Base URL to work off                         
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Counter to go through data
record = 0
sets = 1

# Create DataFrame
weather_df = pd.DataFrame({"City": cities})

weather_df["Country"] = ""
weather_df["Date"] = ""      
weather_df["Latitude"] = ""
weather_df["Longitude"] = ""
weather_df["Cloudiness (%)"] = ""
weather_df["Humidity (%)"] = ""
weather_df["Max Temp (F)"] = ""
weather_df["Wind Speed (mph)"] = ""


# Interate through Cities and retrieve data
print("Beginning Data Retrieval")
print("-----------------------------")


for index, row in weather_df.iterrows():
    
    city = row["City"]
    
    query_url = base_url + "appid=" + weather_api_key + "&q=" + city
    weather_response = requests.get(query_url).json()
 
    try:
        print(f"Processing Record {record}  of Set {sets} | {city}.")
        #print (query_url) 
        
        weather_df.loc[index, "Country"] = weather_response["sys"]["country"]     
        weather_df.loc[index, "Date"] = datetime.datetime.fromtimestamp(weather_response["dt"])
        weather_df.loc[index, "Latitude"] = weather_response["coord"]["lat"]
        weather_df.loc[index, "Longitude"] = weather_response["coord"]["lon"]
        weather_df.loc[index, "Cloudiness (%)"] = weather_response["clouds"]["all"]
        weather_df.loc[index, "Humidity (%)"] = weather_response["main"]["humidity"]
        weather_df.loc[index, "Max Temp (F)"] = 1.8 * (weather_response["main"]["temp_max"] - 273) + 32
        weather_df.loc[index, "Wind Speed (mph)"] = weather_response["wind"]["speed"]
               
    except:
        print(f"City not found...skipping {city}.")
        #print (query_url) 
        
    
    record = record + 1
    if record == 50:
        record = 0
        sets = sets + 1 

print("-----------------------------")        
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0  of Set 1 | praya.
# Processing Record 1  of Set 1 | chokurdakh.
# Processing Record 2  of Set 1 | vila franca do campo.
# Processing Record 3  of Set 1 | ushuaia.
# Processing Record 4  of Set 1 | butaritari.
# Processing Record 5  of Set 1 | dikson.
# Processing Record 6  of Set 1 | illoqqortoormiut.
# City not found...skipping illoqqortoormiut.
# Processing Record 7  of Set 1 | udachnyy.
# Processing Record 8  of Set 1 | taolanaro.
# City not found...skipping taolanaro.
# Processing Record 9  of Set 1 | kapaa.
# Processing Record 10  of Set 1 | puerto ayora.
# Processing Record 11  of Set 1 | christchurch.
# Processing Record 12  of Set 1 | port elizabeth.
# Processing Record 13  of Set 1 | qaanaaq.
# Processing Record 14  of Set 1 | busselton.
# Processing Record 15  of Set 1 | georgetown.
# Processing Record 16  of Set 1 | asheboro.
# Processing Record 17  of Set 1 | general roca.
# Processing Record 18  of Set 1 | priladozhskiy.
# Processing Record 19  of Set 1 | rakoczifalva.
# Processing Record 20  of Set 1 | torbay.
# Processing Record 21  of Set 1 | miri.
# Processing Record 22  of Set 1 | shingu.
# Processing Record 23  of Set 1 | molina.
# Processing Record 24  of Set 1 | utiroa.
# City not found...skipping utiroa.
# Processing Record 25  of Set 1 | nikolskoye.
# Processing Record 26  of Set 1 | bluff.
# Processing Record 27  of Set 1 | abu kamal.
# Processing Record 28  of Set 1 | mataura.
# Processing Record 29  of Set 1 | xianshuigu.
# Processing Record 30  of Set 1 | isangel.
# Processing Record 31  of Set 1 | ketchikan.
# Processing Record 32  of Set 1 | oranjemund.
# Processing Record 33  of Set 1 | bereda.
# Processing Record 34  of Set 1 | dingle.
# Processing Record 35  of Set 1 | haibowan.
# City not found...skipping haibowan.
# Processing Record 36  of Set 1 | barentsburg.
# City not found...skipping barentsburg.
# Processing Record 37  of Set 1 | norman wells.
# Processing Record 38  of Set 1 | tanete.
# Processing Record 39  of Set 1 | vardo.
# Processing Record 40  of Set 1 | makakilo city.
# Processing Record 41  of Set 1 | raudeberg.
# Processing Record 42  of Set 1 | leningradskiy.
# Processing Record 43  of Set 1 | qaqortoq.
# Processing Record 44  of Set 1 | belushya guba.
# City not found...skipping belushya guba.
# Processing Record 45  of Set 1 | sambava.
# Processing Record 46  of Set 1 | patu.
# Processing Record 47  of Set 1 | amderma.
# City not found...skipping amderma.
# Processing Record 48  of Set 1 | tiksi.
# Processing Record 49  of Set 1 | kirovskiy.
# Processing Record 0  of Set 2 | hobart.
# Processing Record 1  of Set 2 | attawapiskat.
# City not found...skipping attawapiskat.
# Processing Record 2  of Set 2 | narsaq.
# Processing Record 3  of Set 2 | atuona.
# Processing Record 4  of Set 2 | rikitea.
# Processing Record 5  of Set 2 | buta.
# Processing Record 6  of Set 2 | tikrit.
# Processing Record 7  of Set 2 | crab hill.
# City not found...skipping crab hill.
# Processing Record 8  of Set 2 | muros.
# Processing Record 9  of Set 2 | punta arenas.
# Processing Record 10  of Set 2 | grand centre.
# City not found...skipping grand centre.
# Processing Record 11  of Set 2 | svetlaya.
# Processing Record 12  of Set 2 | quelimane.
# Processing Record 13  of Set 2 | kangaatsiaq.
# Processing Record 14  of Set 2 | tarauaca.
# Processing Record 15  of Set 2 | husavik.
# Processing Record 16  of Set 2 | fairbanks.
# Processing Record 17  of Set 2 | la paz.
# Processing Record 18  of Set 2 | payo.
# Processing Record 19  of Set 2 | kodiak.
# Processing Record 20  of Set 2 | bonavista.
# Processing Record 21  of Set 2 | saleaula.
# City not found...skipping saleaula.
# Processing Record 22  of Set 2 | wangdiphodrang.
# City not found...skipping wangdiphodrang.
# Processing Record 23  of Set 2 | mnogovershinnyy.
# Processing Record 24  of Set 2 | waingapu.
# Processing Record 25  of Set 2 | vao.
# Processing Record 26  of Set 2 | hermanus.
# Processing Record 27  of Set 2 | jamestown.
# Processing Record 28  of Set 2 | iralaya.
# Processing Record 29  of Set 2 | velykoploske.
# Processing Record 30  of Set 2 | tuktoyaktuk.
# Processing Record 31  of Set 2 | port alfred.
# Processing Record 32  of Set 2 | mys shmidta.
# City not found...skipping mys shmidta.
# Processing Record 33  of Set 2 | drabiv.
# Processing Record 34  of Set 2 | nizhneyansk.
# City not found...skipping nizhneyansk.
# Processing Record 35  of Set 2 | lavrentiya.
# Processing Record 36  of Set 2 | saldanha.
# Processing Record 37  of Set 2 | samusu.
# City not found...skipping samusu.
# Processing Record 38  of Set 2 | warman.
# Processing Record 39  of Set 2 | albany.
# Processing Record 40  of Set 2 | cape town.
# Processing Record 41  of Set 2 | banjar.
# Processing Record 42  of Set 2 | santa lucia.
# Processing Record 43  of Set 2 | kudahuvadhoo.
# Processing Record 44  of Set 2 | shelopugino.
# Processing Record 45  of Set 2 | demmin.
# Processing Record 46  of Set 2 | vizinga.
# Processing Record 47  of Set 2 | zwedru.
# Processing Record 48  of Set 2 | plonsk.
# Processing Record 49  of Set 2 | nikolayevskaya.
# Processing Record 0  of Set 3 | longyearbyen.
# Processing Record 1  of Set 3 | new norfolk.
# Processing Record 2  of Set 3 | tariba.
# Processing Record 3  of Set 3 | broome.
# Processing Record 4  of Set 3 | tasiilaq.
# Processing Record 5  of Set 3 | kingsport.
# Processing Record 6  of Set 3 | sabzevar.
# Processing Record 7  of Set 3 | kenai.
# Processing Record 8  of Set 3 | kyren.
# Processing Record 9  of Set 3 | gizo.
# Processing Record 10  of Set 3 | lebanon.
# Processing Record 11  of Set 3 | hilo.
# Processing Record 12  of Set 3 | saint george.
# Processing Record 13  of Set 3 | north bend.
# Processing Record 14  of Set 3 | marsa matruh.
# Processing Record 15  of Set 3 | merauke.
# Processing Record 16  of Set 3 | tarazona.
# Processing Record 17  of Set 3 | khatanga.
# Processing Record 18  of Set 3 | tombouctou.
# Processing Record 19  of Set 3 | cabo san lucas.
# Processing Record 20  of Set 3 | la asuncion.
# Processing Record 21  of Set 3 | vaini.
# Processing Record 22  of Set 3 | port lincoln.
# Processing Record 23  of Set 3 | sal rei.
# Processing Record 24  of Set 3 | nome.
# Processing Record 25  of Set 3 | nador.
# Processing Record 26  of Set 3 | aksarka.
# Processing Record 27  of Set 3 | berlevag.
# Processing Record 28  of Set 3 | balabac.
# Processing Record 29  of Set 3 | mount gambier.
# Processing Record 30  of Set 3 | noumea.
# Processing Record 31  of Set 3 | katsuura.
# Processing Record 32  of Set 3 | bathsheba.
# Processing Record 33  of Set 3 | souillac.
# Processing Record 34  of Set 3 | dwarka.
# Processing Record 35  of Set 3 | kokopo.
# Processing Record 36  of Set 3 | barrow.
# Processing Record 37  of Set 3 | kawana waters.
# City not found...skipping kawana waters.
# Processing Record 38  of Set 3 | sarishabari.
# Processing Record 39  of Set 3 | iberia.
# Processing Record 40  of Set 3 | bethal.
# Processing Record 41  of Set 3 | bengkulu.
# Processing Record 42  of Set 3 | bredasdorp.
# Processing Record 43  of Set 3 | lebu.
# Processing Record 44  of Set 3 | abnub.
# Processing Record 45  of Set 3 | vaitupu.
# City not found...skipping vaitupu.
# Processing Record 46  of Set 3 | college.
# Processing Record 47  of Set 3 | butajira.
# Processing Record 48  of Set 3 | kroya.
# Processing Record 49  of Set 3 | olafsvik.
# Processing Record 0  of Set 4 | rio brilhante.
# Processing Record 1  of Set 4 | northam.
# Processing Record 2  of Set 4 | avarua.
# Processing Record 3  of Set 4 | olinda.
# Processing Record 4  of Set 4 | yerbogachen.
# Processing Record 5  of Set 4 | katsiveli.
# City not found...skipping katsiveli.
# Processing Record 6  of Set 4 | thompson.
# Processing Record 7  of Set 4 | hithadhoo.
# Processing Record 8  of Set 4 | esperance.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Data Count
weather_df.count()
# Out:
# City                627
# Country             627
# Date                627
# Latitude            627
# Longitude           627
# Cloudiness (%)      627
# Humidity (%)        627
# Max Temp (F)        627
# Wind Speed (mph)    627
# dtype: int64

# %%
# Display DataFrame
weather_df.head()
# Out:
#                    City Country                 Date Latitude Longitude  \
# 0                 praya      CV  2022-08-01 16:25:59  14.9215  -23.5087
# 1            chokurdakh      RU  2022-08-01 16:21:16  70.6333  147.9167
# 2  vila franca do campo      PT  2022-08-01 16:21:42  37.7167  -25.4333
# 3               ushuaia      AR  2022-08-01 16:19:14    -54.8     -68.3
# 4            butaritari      KI  2022-08-01 16:20:47   3.0707  172.7902
#
#   Cloudiness (%) Humidity (%) Max Temp (F) Wind Speed (mph)
# 0             75           69        77.81             1.54
# 1             99           82       49.316             4.88
# 2             92           77       72.284             0.85
# 3             20           57       48.128              3.6
# 4            100           79        81.59              6.5

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Convert data strings to float
pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float)
pd.to_numeric(weather_df["Humidity (%)"]).astype(float)
pd.to_numeric(weather_df["Latitude"]).astype(float)
pd.to_numeric(weather_df["Longitude"]).astype(float)
pd.to_numeric(weather_df["Max Temp (F)"]).astype(float)
pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float)
weather_df

#Export DataFrame to CSV File
weather_df.to_csv("weather_df.csv")

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Max Temp (F)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs Max Temperature ({today})")
print("The plot proves that as we generally move away from the equator, temperature drops")
# Out:
# The plot proves that as we generally move away from the equator, temperature drops

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Humidity (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity (%) ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and humidity")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs Wind Speed ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()
# Out:
# Regression line equation is: y = -0.44x + 89.44
# The r-squared is: -0.6496386181029989
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()
# Out:
# Regression line equation is: y = 0.71x + 80.4
# The r-squared is: 0.7878574330290705
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# Regression line equation is: y = -0.02x + 72.72
# The r-squared is: -0.021048054182537034
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.11x + 75.48
# The r-squared is: 0.07061693108179891
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.09x + 63.62
# The r-squared is: -0.048069852233303234
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.45x + 59.2
# The r-squared is: 0.1623723322219417
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.02x + 4.2
# The r-squared is: -0.15169310262281357
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.02x + 3.21
# The r-squared is: -0.12582845679080293
# The regression does not display much of a correlation between the data sets.
